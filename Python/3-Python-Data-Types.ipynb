# %%
# Data Types in Pyhton

#  --->   data types are the ancalssification of data which tell the compiler or interpreter how the programmer inted to use the data 

#   --->  they determines the types of oprational that can be perfromed on the data bthe valyue that the data can take and the amount of money needed to store the data

# %%
#  1  Integer Data Type 

age = 23
print(type(age))
print(age)
# Out:
# <class 'int'>
# 23

# %%
# 2 Float Data Type

height = 5.9
print(type(height))
print(height)
# Out:
# <class 'float'>
# 5.9

# %%
# 3 String Data Type

name = "Aniket"
print(type(name))
print(name)
# Out:
# <class 'str'>
# Aniket

# %%
#  4 Boolean Data Type


trueOrFalse = True
print(type(trueOrFalse))
print(trueOrFalse)



trueOrFalse1 = False
print(type(trueOrFalse))
print(trueOrFalse1)
# Out:
# <class 'bool'>
# True
# <class 'bool'>
# False
