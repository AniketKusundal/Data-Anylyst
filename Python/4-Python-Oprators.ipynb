# %%
#  Arithmatic Oprators


a = 55
b = 18


print(a + b )
print(a - b )
print(a * b )
print(a / b )
print(a % b )
print(a // b )    # --> floor dividsion it removes the decimal at given only exact value
# Out:
# 73
# 37
# 990
# 3.0555555555555554
# 1
# 3

# %%
# Comparison Oprator 
# 1  ( ==  )
c = 12
d = 12

print(c == d )
# Out:
# True

# %%
# 2  ( != )

x = "Aniket"
y = "aniket"

print(x != y)
# Out:
# False

# %%
#  3 Grater Than  ( > )

num1 = 52
num2 = 53


num1 > num2
# Out:
# False

# %%
#  4 Less Than 

num3 = 54
num4 = 65

num3 < num3
# Out:
# False

# %%
# 5 Grater Than Or Equal To 

num5 = 85
num6 = 75

num5 >= num6
# Out:
# True

# %%
# 5 Less Than Or Equal To 

num5 = 85
num6 = 75

num5 <= num6
# Out:
# False

# %%
# Logical Oprator 

#  1 AND Oprator 

X = True
Y = False


result = X and Y
print(result)
# Out:
# False

# %%
#  2 OR Oprator 

X = True
Y = False


result = X or Y
print(result)
# Out:
# True

# %%
Z = True

print( not Z)
# Out:
# False
