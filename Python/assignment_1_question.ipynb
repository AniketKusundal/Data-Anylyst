# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
print(input("Enter Your Name"))
# Out:
# aniket

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
num = 5

if num == 0:
    print("Number Is Zero")
elif num >= 0:
    print("Number Is Positive")
else:
    print("Number Is Negative")
# Out:
# Number Is Negative

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
number1 = 20
number2 = 50
number3 = 90


if number1 > number2:
    print("Number 1 is grather than Number 2 And Number 3" , number1)
elif number2 >number3:
    print("Number 2 Is Grater Than Number 1 And Number 3" , number2)
else:
    print("Number 3 Is Grather Than Number 1 And Number 2" , number3)
# Out:
# Number 3 Is Grather Than Number 1 And Number 2 90

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
num = int(input("Enter the number : "))

factorial = 1

if num < 0:
    print("Factorial Does Not Exist For The Negative Number ")
elif num == 0:
    print("factorial Of 0 Is 1 ")
else:
    for i in range(1 , num +1):
        factorial = factorial * i
    print(f"The Factorial Of {num} is {factorial}")
# Out:
# The Factorial Of 4 is 24

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
num = 32
decimal = 1.009
name = "Aniket"
is_vote = True


print(type(num))  
print(type(decimal))  
print(type(name))  
print(type(is_vote))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
num1 = 10
num2 = 28

print("Before Swapping")
print(num1)
print(num2)


temp = num1
num1 = num2
num2 = temp

print("After Swaping")

print(num1)
print(num2)

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
Celsius = int(input("Enter The number for the convert to Celsius To Fahrenheit : "))

faherenheit = (Celsius * 9/5) +32 

print(faherenheit)
# Out:
# 50.0

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
# Your code here

str1 = "Aniket"
str2 = "Kusundal"


combine = str1 + " " + str2

print(combine)
# Out:
# Aniket Kusundal

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
user_input =5.22

if isinstance(user_input , int):
    print("The Variable Type Is Integer")
elif isinstance(user_input , float):
    print("The Varibale Type Is Float")
elif isinstance(user_input , str):
    print("The variable type is string")
elif isinstance(user_input , bool):
    printf("The Variable Type is Bool")
else:
    print("Invalid Data type")
# Out:
# The Varibale Type Is Float

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
num1 = float(input("Enter The First Number :"))
num2 = float(input("Enter The Second Number :"))

sum = num1 + num2
sub = num2 - num1
mul = num1 * num2
div = num2 / num1
mod = num2 % num1

print("Sum :" , sum)
print("Subtraction :" , sub)
print("Multiplication :" , mul)
print("Division :" , div)
print("Modulus :" , mod)
# Out:
# Sum : 50.0
# Subtraction : 0.0
# Multiplication : 625.0
# Division : 1.0
# Modulus : 0.0

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
# Input two numbers
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

# Equal to (==)
print("Equal to (==):", num1 == num2)

# Not equal to (!=)
print("Not equal to (!=):", num1 != num2)

# Greater than (>)
print("Greater than (>):", num1 > num2)

# Less than (<)
print("Less than (<):", num1 < num2)
# Out:
# Equal to (==): False
# Not equal to (!=): True
# Greater than (>): True
# Less than (<): False

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
a = True
b = False

# Logical AND
print("a and b" , a and b)

# Logical OR
print("a or b" , a or b)

# Logical NOT
print("a NOT b" ,  not a)
print("a NOT b" ,  not b)
# Out:
# a and b False
# a or b True
# a NOT b False
# a NOT b True

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
num = int(input("Enter a Number :"))
square = num * num 
print("Square of the Number is :" , square)
# Out:
# Square of the Number is : 64

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
num = int(input("Enter A Number : "))


if num == 0:
    print("Number is Zero")
elif num % 2 == 0:
    print("Number Is Even")
else:
    print("The Number IS odd")
# Out:
# Number Is Even

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
num = int(input("Enter The Number : "))

total = 0

for i in range(1 , num + 1):
    total += i

print("The sum of N Natural Number Is " , total)
# Out:
# The sum of N Natural Number Is  55

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
year  = int(input("Enter a Year : "))

if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print(f"{year} Is a Leap Year")
else:
    print(f"{year} Is Not A Leap Year")
# Out:
# 2032 Is a Leap Year

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
str1 = "ANIKET IS LEARNING PYTHON"

str1[::-1]
# Out:
# 'NOHTYP GNINRAEL SI TEKINA'

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
text = input("Enter A Text :")

reverse_text = text[::-1]

if text == reverse_text:
    print("The TExt Is A Palindrome")
else:
    print("The Text Is Not A Palindrome")
# Out:
# The TExt Is A Palindrome

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
list1 = [30 , 49 , 10 , 2 , 60 , 77 , 33 , 22]

print(list1)

print("List After Sorting")

list1.sort()
print(list1)
# Out:
# [30, 49, 10, 2, 60, 77, 33, 22]
# List After Sorting
# [2, 10, 22, 30, 33, 49, 60, 77]
